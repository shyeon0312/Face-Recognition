# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/week2/data/input_trim')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow

# List the images in the folder:
img_list = os.listdir()

input_images = []
for img in img_list:
    image = cv2.imread(img)
    input_images.append(image)

# %%
# from rembg import remove

# # input_path = input_images[0]
# output_path = '..test_output.png'

# input = input_images[1].copy()
# output = remove(input)
# cv2.imwrite(output_path, output)
# Out:
# True

# %%
img_list[0][:-8]
# Out:
# '남성_27_'

# %%
from tqdm import tqdm

output_path = '../input_trim_no_bg/'

for idx, img in enumerate(tqdm(input_images)):
  output_name = output_path + img_list[idx][:-8] + '배경제거.png'
  input = img
  if input is not None:
    output = remove(input)
    cv2.imwrite(output_name, output)
# Out:
# 100%|██████████| 94/94 [03:43<00:00,  2.38s/it]
